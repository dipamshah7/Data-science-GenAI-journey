# %%
#Tuples (Immutable Lists)
coordinates = (10.5, 20.3, 30.7)

print(coordinates)
print(type(coordinates))

# Accessing items
print(coordinates[0])
print(coordinates[-1])

# Length
print(len(coordinates))
